# %%
import pandas as pd
df = pd.DataFrame({'col1':[1,2,3,4], 'col2':[444,555,666,444], 'col3':['abc', 'def', 'ghi', 'xyz']})
df.head()
# Out:
#    col1  col2 col3
# 0     1   444  abc
# 1     2   555  def
# 2     3   666  ghi
# 3     4   444  xyz

# %%
df['col2'].unique()
# get unique values of a column
# Out:
# array([444, 555, 666])

# %%
df['col2'].nunique()
# get the number of unique values
# Out:
# 3

# %%
df['col2'].value_counts()
# get unqiue values and count the amount in a column
# Out:
# col2
# 444    2
# 555    1
# 666    1
# Name: count, dtype: int64

# %%
newdf = df[(df['col1'] > 2) & (df['col2'] == 444)]
newdf
# create a new dataframe based on df, where the value of col1 is greather then 2 and col2 is equal 444
# Out:
#    col1  col2 col3
# 3     4   444  xyz

# %%
def multiply2(x):
    return x * 2
# define a function that multiplies by 2

# %%
df['col2'].apply(multiply2)
# apply the function to column 2
# Out:
# 0     888
# 1    1110
# 2    1332
# 3     888
# Name: col2, dtype: int64

# %%
df['col3'].apply(len)
# return the string length of column 3 with the len function
# Out:
# 0    3
# 1    3
# 2    3
# 3    3
# Name: col3, dtype: int64

# %%
df['col2'].apply(lambda x: x * 2)
# Out:
# 0     888
# 1    1110
# 2    1332
# 3     888
# Name: col2, dtype: int64

# %%
df['col2'].min()
# Out:
# 444

# %%
df.drop('col2', axis = 1)
# remove a column from a dataframe (not permanent)
# Out:
#    col1 col3
# 0     1  abc
# 1     2  def
# 2     3  ghi
# 3     4  xyz

# %%
del df['col1']
# delete a column from a dataframe

# %%
df
# Out:
#    col2 col3
# 0   444  abc
# 1   555  def
# 2   666  ghi
# 3   444  xyz

# %%
df.columns
# return all column names
# Out:
# Index(['col2', 'col3'], dtype='object')

# %%
df.index
# information about the rows
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
df
# Out:
#    col2 col3
# 0   444  abc
# 1   555  def
# 2   666  ghi
# 3   444  xyz

# %%
df.sort_values(by = 'col2', ascending = False, inplace = True)
# sort the dataframe by column 2 descending

# %%
df
# Out:
#    col2 col3
# 2   666  ghi
# 1   555  def
# 0   444  abc
# 3   444  xyz

# %%
df.isnull()
# returns null values of the dataframe
# Out:
#     col2   col3
# 2  False  False
# 1  False  False
# 0  False  False
# 3  False  False

# %%
df.dropna()
# Out:
#    col2 col3
# 2   666  ghi
# 1   555  def
# 0   444  abc
# 3   444  xyz

# %%
import numpy as np
df = pd.DataFrame({'col1':[1,2,3,np.nan],
                   'col2':[np.nan,555,666,444],
                   'col3':['abc','def','ghi','xyz']})
df.head()
# Out:
#    col1   col2 col3
# 0   1.0    NaN  abc
# 1   2.0  555.0  def
# 2   3.0  666.0  ghi
# 3   NaN  444.0  xyz

# %%
df.fillna(0)
# fill NaN values with 0
# Out:
#    col1   col2 col3
# 0   1.0    0.0  abc
# 1   2.0  555.0  def
# 2   3.0  666.0  ghi
# 3   0.0  444.0  xyz

# %%
df['col1'] = df['col1'].fillna(df['col1'].mean())
df['col2'] = df['col2'].fillna(df['col2'].mean())
# fill the NaN values of the two columns with their mean value

# %%
df
# Out:
#    col1   col2 col3
# 0   1.0  555.0  abc
# 1   2.0  555.0  def
# 2   3.0  666.0  ghi
# 3   2.0  444.0  xyz

# %%
data = {'A':['foo','foo','foo','bar','bar','bar'],
     'B':['one','one','two','two','one','one'],
       'C':['x','y','x','y','x','y'],
       'D':[1,3,2,5,4,1]}

df = pd.DataFrame(data)

# %%
df
# Out:
#      A    B  C  D
# 0  foo  one  x  1
# 1  foo  one  y  3
# 2  foo  two  x  2
# 3  bar  two  y  5
# 4  bar  one  x  4
# 5  bar  one  y  1

# %%
df.pivot_table(values = 'D', index = ['A','B'], columns = ['C'])
# pivoting a table
# Out:
# C          x    y
# A   B
# bar one  4.0  1.0
#     two  NaN  5.0
# foo one  1.0  3.0
#     two  2.0  NaN
