# %%
import numpy as np
import pandas as pd

# %%
labels = ['a', 'b', 'c']
list = [10,20,30]
arr = np.array(list)
d = {'a' : 10, 'b' : 20, 'c': 30}

# %%
pd.Series(data = list)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
pd.Series(data = list, index = labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(arr, labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(d)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(labels)
# Out:
# 0    a
# 1    b
# 2    c
# dtype: object

# %%
pd.Series([sum, print, len])
# Out:
# 0      <built-in function sum>
# 1    <built-in function print>
# 2      <built-in function len>
# dtype: object

# %%
ser1 = pd.Series([1,2,3,4], index = ['Deutschland', 'Frankreich', 'Norwegen', 'Schweden'])

# %%
ser1
# Out:
# Deutschland    1
# Frankreich     2
# Norwegen       3
# Schweden       4
# dtype: int64

# %%
ser2 = pd.Series([5,6,7,8], index = ['Deutschland', 'Frankreich', 'Italien', 'Schweden'])

# %%
ser2
# Out:
# Deutschland    5
# Frankreich     6
# Italien        7
# Schweden       8
# dtype: int64

# %%
ser1['Deutschland']
# Out:
# np.int64(1)

# %%
ser1 + ser2
# Out:
# Deutschland     6.0
# Frankreich      8.0
# Italien         NaN
# Norwegen        NaN
# Schweden       12.0
# dtype: float64
