# %%
import numpy as np
import pandas as pd
# %matplotlib inline

# %%
df1 = pd.read_csv('./examples/df1', index_col = 0)
df2 = pd.read_csv('./examples/df2')

# %%
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
df1['A'].hist()
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %%
df1['A'].hist()
# Out:
# <Axes: >

# %%
df2.plot.area(alpha = 0.5)
# Out:
# <Axes: >

# %%
df2.plot.bar()
# Out:
# <Axes: >

# %%
df2.plot.bar(stacked = True)
# stacked bar plot
# Out:
# <Axes: >

# %%
df1['A'].plot.hist(bins = 50)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df1.plot.line()
# Out:
# <Axes: >

# %%
df1.plot.line(y = 'B', figsize = (12,3), linewidth = 1)
# Out:
# <Axes: >

# %%
df1.plot.scatter(x = 'A', y = 'B', c = 'C', s = df1['C'] * 100, cmap = 'magma', figsize = (10,10))
# scatterplot with point size and colour based on column 'C'
# Out:
# /home/eric/anaconda3/lib/python3.13/site-packages/matplotlib/collections.py:999: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor
# <Axes: xlabel='A', ylabel='B'>

# %%
df2.plot.box()
# Out:
# <Axes: >

# %%
df = pd.DataFrame(np.random.randn(1000, 2), columns = ['a', 'b'])
# random dataframe with 1000 numbers from -1 to 1

# %%
df.head()
# Out:
#           a         b
# 0 -0.517756  0.085106
# 1  0.026170 -1.469219
# 2 -1.359567  0.395847
# 3 -0.098111  1.118465
# 4  0.656584  1.797983

# %%
df.plot.hexbin(x = 'a', y = 'b', cmap = 'magma', gridsize = 50, figsize = (12,10))
# Out:
# <Axes: xlabel='a', ylabel='b'>

# %%
df2.plot.density()
# kde for all columns
# Out:
# <Axes: ylabel='Density'>

# %%
df2['a'].plot.kde()
# kde for a single column
# Out:
# <Axes: ylabel='Density'>
